# %% [markdown]
# <a href="https://colab.research.google.com/github/saadz-khan/StyleGAN-client/blob/master/final_style_transfer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# If you are running in colab, select tensorflow version 1.x:

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %% [markdown]
# Or, if running locally, you need tensorflow version below 2

# %%
# !pip install -q 'scipy<=1.2.1'  # scipy.misc.imread is deprecated in later versions
# Out:
#      |████████████████████████████████| 24.8 MB 1.6 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lucid 0.3.10 requires umap-learn, which is not installed.
# lucid 0.3.10 requires numpy<=1.19, but you have numpy 1.19.5 which is incompatible.
# kapre 0.3.6 requires tensorflow>=2.0.0, but you have tensorflow 1.15.2 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.

# %%
# !git clone https://github.com/titu1994/Neural-Style-Transfer.git
# Out:
# Cloning into 'Neural-Style-Transfer'...
# remote: Enumerating objects: 1411, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 1411 (delta 5), reused 6 (delta 1), pack-reused 1393
# Receiving objects: 100% (1411/1411), 68.18 MiB | 20.02 MiB/s, done.
# Resolving deltas: 100% (824/824), done.

# %%
# !mkdir Neural-Style-Transfer
dir_path = "Neural-Style-Transfer"
# Out:
# mkdir: cannot create directory ‘Neural-Style-Transfer’: File exists

# %% [markdown]
# # Network Type
#
# Choose the network type below :
#
# - "Network" for the original style transfer
# - "INetwork" for the improved style transfer (default)

# %%
NETWORK = 'INetwork' + '.py'

# %%
# List all the arguments that can be supplied to Network.py
# !python {dir_path}/{NETWORK} -h
# Out:
# Using TensorFlow backend.
# usage: INetwork.py [-h] [--style_masks STYLE_MASKS [STYLE_MASKS ...]]
#                    [--content_mask CONTENT_MASK] [--color_mask COLOR_MASK]
#                    [--image_size IMG_SIZE] [--content_weight CONTENT_WEIGHT]
#                    [--style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]]
#                    [--style_scale STYLE_SCALE]
#                    [--total_variation_weight TV_WEIGHT] [--num_iter NUM_ITER]
#                    [--model MODEL] [--content_loss_type CONTENT_LOSS_TYPE]
#                    [--rescale_image RESCALE_IMAGE]
#                    [--rescale_method RESCALE_METHOD]
#                    [--maintain_aspect_ratio MAINTAIN_ASPECT_RATIO]
#                    [--content_layer CONTENT_LAYER] [--init_image INIT_IMAGE]
#                    [--pool_type POOL] [--preserve_color COLOR]
#                    [--min_improvement MIN_IMPROVEMENT]
#                    base ref [ref ...] res_prefix
#
# Neural style transfer with Keras.
#
# positional arguments:
#   base                  Path to the image to transform.
#   ref                   Path to the style reference image.
#   res_prefix            Prefix for the saved results.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --style_masks STYLE_MASKS [STYLE_MASKS ...]
#                         Masks for style images
#   --content_mask CONTENT_MASK
#                         Masks for the content image
#   --color_mask COLOR_MASK
#                         Mask for color preservation
#   --image_size IMG_SIZE
#                         Minimum image size
#   --content_weight CONTENT_WEIGHT
#                         Weight of content
#   --style_weight STYLE_WEIGHT [STYLE_WEIGHT ...]
#                         Weight of style, can be multiple for multiple styles
#   --style_scale STYLE_SCALE
#                         Scale the weighing of the style
#   --total_variation_weight TV_WEIGHT
#                         Total Variation weight
#   --num_iter NUM_ITER   Number of iterations
#   --model MODEL         Choices are 'vgg16' and 'vgg19'
#   --content_loss_type CONTENT_LOSS_TYPE
#                         Can be one of 0, 1 or 2. Readme contains the required
#                         information of each mode.
#   --rescale_image RESCALE_IMAGE
#                         Rescale image after execution to original dimentions
#   --rescale_method RESCALE_METHOD
#                         Rescale image algorithm
#   --maintain_aspect_ratio MAINTAIN_ASPECT_RATIO
#                         Maintain aspect ratio of loaded images
#   --content_layer CONTENT_LAYER
#                         Content layer used for content loss.
#   --init_image INIT_IMAGE
#                         Initial image used to generate the final image.
#                         Options are 'content', 'noise', or 'gray'
#   --pool_type POOL      Pooling type. Can be "ave" for average pooling or
#                         "max" for max pooling
#   --preserve_color COLOR
#                         Preserve original color in image
#   --min_improvement MIN_IMPROVEMENT
#                         Defines minimum improvement required to continue
#                         script

# %% [markdown]
# # Network Parameters
#
# Here, we will setup all of the parameters for the `Network.py` script.

# %%
# Image size
IMAGE_SIZE = 1024

# Loss Weights
CONTENT_WEIGHT = 0.025
STYLE_WEIGHT = 1.0
STYLE_SCALE = 1.0
TOTAL_VARIATION_WEIGHT = 8.5e-5
CONTENT_LOSS_TYPE = 0

# Training arguments
NUM_ITERATIONS = 10
MODEL = 'vgg19'
RESCALE_IMAGE = 'false'
MAINTAIN_ASPECT_RATIO = 'false'  # Set to false if OOM occurs

# Transfer Arguments
CONTENT_LAYER = 'conv' + '5_2'  # only change the number 5_2 to something in a similar format
INITIALIZATION_IMAGE = 'content'
POOLING_TYPE = 'max'

# Extra arguments
PRESERVE_COLOR = 'false'
MIN_IMPROVEMENT = 0.0

# %% [markdown]
# # Content Image
#
# Run the below cell to upload the Content Image. Make sure to select **just 1 image**

# %%
from google.colab import files

content_img = files.upload()
#content_img = open('/content/seed0003.png')
# Out:
#      <input type="file" id="files-c8768fdf-7a68-4d9c-bd65-1d1cdedd2c6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8768fdf-7a68-4d9c-bd65-1d1cdedd2c6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 00000000.jpg to 00000000.jpg

# %%
import os

CONTENT_IMAGE_FN = list(content_img)[0]
CONTENT_IMAGE_FN_temp = CONTENT_IMAGE_FN.strip().replace(" ", "_")

if CONTENT_IMAGE_FN != CONTENT_IMAGE_FN_temp:
  os.rename(CONTENT_IMAGE_FN, CONTENT_IMAGE_FN_temp)
  CONTENT_IMAGE_FN = CONTENT_IMAGE_FN_temp
  
print("Content image filename :", CONTENT_IMAGE_FN)
# Out:
# Content image filename : 00000000.jpg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10))
img = plt.imread(CONTENT_IMAGE_FN)
plt.axis('off')
plt.title('Content image')
plt.imshow(img)

# %% [markdown]
# # Style Image
#
# Run the below cell to upload the Style Image. Make sure to select **just 1 image**

# %%
style_img = files.upload()
# Out:
#      <input type="file" id="files-af4fd4c2-53a4-47c5-991c-5cdb1cd5d0eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af4fd4c2-53a4-47c5-991c-5cdb1cd5d0eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving seed0003.png to seed0003.png

# %%
STYLE_IMAGE_FN = list(style_img)[0]
STYLE_IMAGE_FN_temp = STYLE_IMAGE_FN.strip().replace(" ", "_")

if STYLE_IMAGE_FN != STYLE_IMAGE_FN_temp:
  os.rename(STYLE_IMAGE_FN, STYLE_IMAGE_FN_temp)
  STYLE_IMAGE_FN = STYLE_IMAGE_FN_temp

print("Style image filename :", STYLE_IMAGE_FN)
# Out:
# Style image filename : seed0003.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(STYLE_IMAGE_FN)
plt.axis('off')
plt.title('Style image')
plt.imshow(img)

# %% [markdown]
# # Generate Image
#
# Run the below cells to generate the image

# %%
import os

RESULT_DIR = "generated/"
RESULT_PREFIX = RESULT_DIR + "gen"
FINAL_IMAGE_PATH = RESULT_PREFIX + "_at_iteration_%d.png" % (NUM_ITERATIONS)

if not os.path.exists(RESULT_DIR):
  os.makedirs(RESULT_DIR)

# %%
# !python {dir_path}/{NETWORK} {CONTENT_IMAGE_FN} {STYLE_IMAGE_FN} {RESULT_PREFIX} \
  --image_size {IMAGE_SIZE} --content_weight {CONTENT_WEIGHT} --style_weight \
  {STYLE_WEIGHT} --style_scale {STYLE_SCALE} --total_variation_weight \
  {TOTAL_VARIATION_WEIGHT} --content_loss_type {CONTENT_LOSS_TYPE} --num_iter \
  {NUM_ITERATIONS} --model {MODEL} --rescale_image {RESCALE_IMAGE} \
  --maintain_aspect_ratio {MAINTAIN_ASPECT_RATIO} --content_layer {CONTENT_LAYER} \
  --init_image {INITIALIZATION_IMAGE} --pool_type {POOLING_TYPE} --preserve_color \
  {PRESERVE_COLOR} --min_improvement {MIN_IMPROVEMENT}
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 4s 0us/step
# 2021-11-20 19:15:36.766784: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-11-20 19:15:36.812265: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:36.812939: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-11-20 19:15:36.824821: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-20 19:15:36.981466: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-20 19:15:37.023687: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-11-20 19:15:37.039634: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-11-20 19:15:37.194598: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-11-20 19:15:37.224112: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-11-20 19:15:37.534614: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-20 19:15:37.534812: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.535546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.536085: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-11-20 19:15:37.554448: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2299995000 Hz
# 2021-11-20 19:15:37.554765: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e143184fc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2021-11-20 19:15:37.554813: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2021-11-20 19:15:37.824407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.825208: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55e143185180 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2021-11-20 19:15:37.825239: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2021-11-20 19:15:37.825406: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.825951: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2021-11-20 19:15:37.826006: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-20 19:15:37.826028: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-20 19:15:37.826048: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2021-11-20 19:15:37.826067: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2021-11-20 19:15:37.826089: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2021-11-20 19:15:37.826142: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2021-11-20 19:15:37.826164: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-20 19:15:37.826249: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.826813: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.827433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1767] Adding visible gpu devices: 0
# 2021-11-20 19:15:37.830506: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2021-11-20 19:15:37.831717: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1180] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-11-20 19:15:37.831752: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1186]      0
# 2021-11-20 19:15:37.831769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1199] 0:   N
# 2021-11-20 19:15:37.832708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.833440: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-20 19:15:37.834078: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-11-20 19:15:37.834187: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1325] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15224 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Model loaded.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Starting iteration 1 of 10
# 2021-11-20 19:15:53.280666: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2021-11-20 19:15:55.794829: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2021-11-20 19:15:59.270251: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.344441: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.70GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.554466: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 448.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.563066: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 579.17MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.563112: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.72GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.563581: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 112.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.563613: W tensorflow/core/kernels/gpu_utils.cc:48] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2021-11-20 19:15:59.649550: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 880.00MiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.664918: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:15:59.664965: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.30GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-11-20 19:16:09.470071: W tensorflow/core/common_runtime/bfc_allocator.cc:419] Allocator (GPU_0_bfc) ran out of memory trying to allocate 192.00MiB (rounded to 201326592).  Current allocation summary follows.
# 2021-11-20 19:16:09.470179: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (256): 	Total Chunks: 50, Chunks in use: 50. 12.5KiB allocated for chunks. 12.5KiB in use in bin. 956B client-requested in use in bin.
# 2021-11-20 19:16:09.470200: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (512): 	Total Chunks: 3, Chunks in use: 3. 1.5KiB allocated for chunks. 1.5KiB in use in bin. 1.5KiB client-requested in use in bin.
# 2021-11-20 19:16:09.470215: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (1024): 	Total Chunks: 6, Chunks in use: 6. 6.2KiB allocated for chunks. 6.2KiB in use in bin. 6.0KiB client-requested in use in bin.
# 2021-11-20 19:16:09.470231: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (2048): 	Total Chunks: 9, Chunks in use: 9. 18.0KiB allocated for chunks. 18.0KiB in use in bin. 18.0KiB client-requested in use in bin.
# 2021-11-20 19:16:09.470245: I tensorflow/core/common_runtime/bfc_allocator.cc:869] Bin (4096): 	Total Chunks: 1, Chunks in use: 1.
I tensorflow/core/common_runtime/bfc_allocator.cc:917] 9 Chunks of size 805306368 totalling 6.75GiB
# 2021-11-20 19:18:09.876072: I tensorflow/core/common_runtime/bfc_allocator.cc:921] Sum Total of in-use chunks: 14.17GiB
# 2021-11-20 19:18:09.876087: I tensorflow/core/common_runtime/bfc_allocator.cc:923] total_region_allocated_bytes_: 15964005888 memory_limit_: 15964005991 available bytes: 103 curr_region_allocation_bytes_: 17179869184
# 2021-11-20 19:18:09.876109: I tensorflow/core/common_runtime/bfc_allocator.cc:929] Stats:
# Limit:                 15964005991
# InUse:                 15213825792
# MaxInUse:              15915060736
# NumAllocs:                     500
# MaxAllocSize:           3640655872
#
# 2021-11-20 19:18:09.876158: W tensorflow/core/common_runtime/bfc_allocator.cc:424] ****************************************************************************************************
# 2021-11-20 19:18:09.876206: W tensorflow/core/framework/op_kernel.cc:1651] OP_REQUIRES failed at transpose_op.cc:198 : Resource exhausted: OOM when allocating tensor with shape[3,256,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Traceback (most recent call last):
#   File "Neural-Style-Transfer/INetwork.py", line 618, in <module>
#     x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(), fprime=evaluator.grads, maxfun=20)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 199, in fmin_l_bfgs_b
#     **opts)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 335, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/lbfgsb.py", line 285, in func_and_grad
#     f = fun(x, *args)
#   File "/usr/local/lib/python3.7/dist-packages/scipy/optimize/optimize.py", line 300, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "Neural-Style-Transfer/INetwork.py", line 562, in loss
#     loss_value, grad_values = eval_loss_and_grads(x)
#   File "Neural-Style-Transfer/INetwork.py", line 540, in eval_loss_and_grads
#     outs = f_outputs([x])
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py", line 3476, in __call__
#     run_metadata=self.run_metadata)
#   File "/tensorflow-1.15.2/python3.7/tensorflow_core/python/client/session.py", line 1472, in __call__
#     run_metadata_ptr)
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[3,256,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradients/strided_slice_42_grad/StridedSliceGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[add_17/_201]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[3,256,256,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradients/strided_slice_42_grad/StridedSliceGrad}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Generated image')
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-0f72d5bfc1cb> in <module>()
#       1 fig = plt.figure(figsize=(10, 10))
# ----> 2 img = plt.imread(FINAL_IMAGE_PATH)
#       3 plt.axis('off')
#       4 plt.title('Generated image')
#       5 plt.imshow(img)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imread(fname, format)
#    2059 @docstring.copy(matplotlib.image.imread)
#    2060 def imread(fname, format=None):
# -> 2061     return matplotlib.image.imread(fname, format)
#    2062
#    2063
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in imread(fname, format)
#    1472             fd = BytesIO(request.urlopen(fname).read())
#    1473             return _png.read_png(fd)
# -> 1474     with cbook.open_file_cm(fname, "rb") as file:
#    1475         return _png.read_png(file)
#    1476
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'generated/gen_at_iteration_10.png'

# %% [markdown]
# # (Optional) Color Transfer
#
# If you wish for color transfer between the content image and the generated image, then run the next cell, else skip to "Download Generated Image" section

# %%
COLOR_TRANSFER = 'color_transfer.py'
COLOR_FINAL_IMAGE_PATH = FINAL_IMAGE_PATH[:-4] + '_%s_color.png'

# Optional - Use Histogram matching (0 for no, 1 for yes)
HISTOGRAM_MATCH = 0

if HISTOGRAM_MATCH == 0:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('original')
else:
  COLOR_FINAL_IMAGE_PATH = COLOR_FINAL_IMAGE_PATH % ('histogram')
  

# !python {dir_path}/{COLOR_TRANSFER} {CONTENT_IMAGE_FN} {FINAL_IMAGE_PATH} --hist_match {HISTOGRAM_MATCH}
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:482: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if issubdtype(ts, int):
# /usr/local/lib/python3.6/dist-packages/scipy/misc/pilutil.py:485: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif issubdtype(type(size), float):
# Image saved at path : generatedgen_at_iteration_15_original_color.png

# %%
fig = plt.figure(figsize=(10, 10))
img = plt.imread(COLOR_FINAL_IMAGE_PATH)
plt.axis('off')
plt.title('Color Transferred Generated image')
plt.imshow(img)

# %% [markdown]
# # Download Color Transfered Image
#
# Run the following cell to download the color transferred result

# %%
# download the color transfered image
files.download(COLOR_FINAL_IMAGE_PATH)

# %% [markdown]
# # Download Generated Image
#
# Run the following cell to download the final result

# %%
files.download(FINAL_IMAGE_PATH)
