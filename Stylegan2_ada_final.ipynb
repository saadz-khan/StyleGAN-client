# %% [markdown]
# <a href="https://colab.research.google.com/github/saadz-khan/StyleGAN-client/blob/master/Stylegan2_ada_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Training StyleGAN2 on Colab
#
# Use Colab Pro+ ($49.99/month), Colab Pro ($10.00/month) to get a couple extra hours of training time in per session and do not run into low-RAM issues.
#
# Recommended: Colab Pro ($10.00 per month)

# %% [markdown]
# # Setting up only once. Kindly check the option
# <center>
#
# ![image](https://media.giphy.com/media/IFRhbMJSy3IaNZulCk/source.gif?cid=790b76116b562dd18158c804953ae06343645e756f8ed52d&rid=source.gif&ct=g)

# %% [markdown]
# # Custom Training StyleGan2-ADA

# %% [markdown]
# StyleGAN2-ADA only work with Tensorflow 1. Run the next cell before anything else to make sure we’re using TF1 and not TF2.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !nvidia-smi
# Out:
# Mon Oct 25 21:45:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Install Repo to Google Drive
#
# Colab is a little funky with training. I’ve found the best way to do this is to install the repo directly into your Google Drive folder.
#
# First, mount your Drive to the Colab notebook: |
#
# ## Mounting Google Drive
# So I’m actually gonna install my entire repo directly into your Google Drive. This will make the setup a little easier.
#
# First, connect your Drive to Colab. Gif explains how to:
#
# <p align="center">
#   <img src="https://media.giphy.com/media/WKMU25D95cjqWw9GCS/source.gif?cid=790b7611b611ba7d6a09693279bea7a3e08cb1e976b1b827&rid=source.gif&ct=g" alt="animated-gif2" />
# </p>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Installing and Updating the Repo
# Next, run this cell. If you’re already installed the repo,
# It will skip the installation process and change into the repo’s directory. If you haven’t installed it, it will install all the files necessary.

# %%
import os
if os.path.isdir("/content/drive/My Drive/colab-sg2-ada"):
    # %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
else:
    #install script
    # %cd "/content/drive/My Drive/"
    # !mkdir colab-sg2-ada
    # %cd colab-sg2-ada
    # !git clone https://github.com/dvschultz/stylegan2-ada
    # %cd stylegan2-ada
    # !mkdir downloads
    # !mkdir datasets
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/colab-sg2-ada
# Cloning into 'stylegan2-ada'...
# remote: Enumerating objects: 364, done.
# remote: Total 364 (delta 0), reused 0 (delta 0), pack-reused 364
# Receiving objects: 100% (364/364), 56.16 MiB | 23.62 MiB/s, done.
# Resolving deltas: 100% (200/200), done.
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %%
# %cd "/content/drive/My Drive/colab-sg2-ada/stylegan2-ada"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git checkout origin/main -- train.py
# Out:
# /content/drive/My Drive/colab-sg2-ada/stylegan2-ada

# %% [markdown]
# ## Adding the dataset (Do not run) For testing

# %%
# !pip install kaggle-cli
# !pip install kaggle
# Out:
# Collecting kaggle-cli
#   Using cached kaggle_cli-0.12.13-py3-none-any.whl
# Requirement already satisfied: beautifulsoup4<4.7,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from kaggle-cli) (4.6.3)
# Collecting cssselect<1.1,>=1.0.1
#   Using cached cssselect-1.0.3-py2.py3-none-any.whl (16 kB)
# Collecting lxml<4.1,>=4.0.0
#   Using cached lxml-4.0.0.tar.gz (4.2 MB)
# Collecting configparser
#   Using cached configparser-5.0.2-py3-none-any.whl (19 kB)
# Collecting cliff<2.9,>=2.8.0
#   Using cached cliff-2.8.3-py2.py3-none-any.whl (74 kB)
# Requirement already satisfied: MechanicalSoup<0.9,>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from kaggle-cli) (0.8.0)
# Requirement already satisfied: progressbar2<3.35,>=3.34.3 in /usr/local/lib/python3.7/dist-packages (from kaggle-cli) (3.34.3)
# Requirement already satisfied: pyparsing>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (2.4.7)
# Requirement already satisfied: PrettyTable<0.8,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (0.7.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (1.15.0)
# Requirement already satisfied: PyYAML>=3.10.0 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (3.13)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (5.6.0)
# Requirement already satisfied: cmd2>=0.6.7 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (2.2.0)
# Requirement already satisfied: stevedore>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from cliff<2.9,>=2.8.0->kaggle-cli) (3.5.0)
# Requirement already satisfied: colorama>=0.3.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (0.4.4)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (1.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (3.7.4.3)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (0.2.5)
# Requirement already satisfied: importlib-metadata>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (4.8.1)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.6.0->cmd2>=0.6.7->cliff<2.9,>=2.8.0->kaggle-cli) (3.6.0)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.7/dist-packages (from MechanicalSoup<0.9,>=0.7.0->kaggle-cli) (2.23.0)
# Requirement already satisfied: python-utils>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from progressbar2<3.35,>=3.34.3->kaggle-cli) (2.5.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->MechanicalSoup<0.9,>=0.7.0->kaggle-cli) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->MechanicalSoup<0.9,>=0.7.0->kaggle-cli) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->MechanicalSoup<0.9,>=0.7.0->kaggle-cli) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0->MechanicalSoup<0.9,>=0.7.0->kaggle-cli) (2.10)
# Building wheels for collected packages: lxml
#   Building wheel for lxml (setup.py) ... error
#   ERROR: Failed building wheel for lxml
#   Running setup.py clean for lxml
# Failed to build lxml
# Installing collected packages: lxml, cssselect, configparser, cliff, kaggle-cli
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#     Running setup.py install for lxml ... error
#   Rolling back uninstall of lxml
#   Moving to /usr/local/lib/python3.7/dist-packages/lxml-4.2.6.dist-info/
#    from /usr/local/lib/python3.7/dist-packages/~xml-4.2.6.dist-info
#   Moving to /usr/local/lib/python3.7/dist-packages/lxml/
#    from /usr/local/lib/python3.7/dist-packages/~xml
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-m7skdes7/lxml_47f982fa42ef4007813b7660e82c962d/setup.py'"'"'; __file__='"'"'/tmp/pip-install-m7skdes7/lxml_47f982fa42ef4007813b7660e82c962d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-c07ooupw/install-record.txt --single-version-externally-managed --compile --install-headers /usr/local/include/python3.7/lxml Check the logs for full command output.
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %%
# %cd /content/drive/My\ Drive/
# !mkdir ./data
# !mkdir ./data/robgon-abstract/
# !mkdir ./data/landscapes/
# Out:
# /content/drive/My Drive
# mkdir: cannot create directory ‘./data’: File exists
# mkdir: cannot create directory ‘./data/robgon-abstract/’: File exists

# %%
# !pip install kaggle -q      # At first, I suspect the kaggle API lose effect so it doesn't have .kaggle folder. (not working)
# !rm -rf /root/.kaggle.      # when I created the folder, it says the file or dir already exits
# !mkdir /root/.kaggle        # successful
# !cp /content/drive/MyDrive/kaggle.json /root/.kaggle/kaggle.json    # not sure if I have to use full destination path, I previously only used /root/.kaggle and it failed. Don't have time to validate this thought.
# !ls /root/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# /root/.kaggle/kaggle.json

# %%
# %cd /content/drive/MyDrive/
#!kaggle datasets download -d robgonsalves/abstract-paintings -p Dataset/abstract-art
# !kaggle datasets download -d arnaud58/landscape-pictures -p Dataset/landscape
# Out:
# /content/drive/MyDrive
# Downloading landscape-pictures.zip to Dataset/landscape
#  98% 609M/620M [00:17<00:00, 52.8MB/s]
# 100% 620M/620M [00:17<00:00, 38.1MB/s]

# %%
#!mkdir /content/drive/MyDrive/Dataset/robgon-abstract
# !unzip /content/drive/MyDrive/Dataset/abstract-art/abstract-paintings.zip -d /content/drive/MyDrive/Dataset/abstract-art
# !rm -rf /content/drive/MyDrive/Dataset/abstract-art/abstract-paintings.zip

# !unzip /content/drive/MyDrive/Dataset/landscape/landscape-pictures.zip -d /content/drive/MyDrive/Dataset/landscape
# !rm -rf /content/drive/MyDrive/Dataset/landscape/landscape-pictures.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_iridescent-interpenetration-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_iridescent-interpenetration-no-13.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_iridescent-interpenetration-no-4-study-of-light-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_iridescent-interpenetration-no-5-eucalyptus-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_iridescent-interpenetration-no-7-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_landscape-1913-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_landscape-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_line-of-speed-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_lines-force-of-boccioni-s-fist.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_lines-of-movement-and-dynamic-succession-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_numbers-in-love-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_pessimism-and-optimism-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_planet-mercury-passing-in-front-of-the-sun-1914-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_planet-mercury-passing-in-front-of-the-sun-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_plastic-colour-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_plastic-ensemble-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_primavera-spring-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_rhythm-noise-speed-of-car-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_science-against-obscurantism-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_september-20-demonstration-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_shape-and-noise-of-motorcyclist-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_speeding-automobile-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_spirit-form-transformation-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_streamlines-futur-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_swifts-paths-of-movement-dynamic-sequences-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_synthesis-of-movement.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_the-speed-of-an-autumobile-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_the-spell-is-broken-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_velocity-of-an-automobile.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_velocity-of-cars-and-light-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_vortex-space-form-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/giacomo-balla_warship-widow-and-wind.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/gino-severini_dancer-in-pigalle-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/gino-severini_sea-dancer-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/gino-severini_simultaniety-of-centrifugal-and-centripedal-groups-woman-at-a-window.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/henryk-berlewi_circle-and-square-in-space-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_altar-painting-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_chaos-nr-2-1906.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_de-tio-st-rsta-n-10-alderdomen-1907.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_de-tio-st-rsta-n-2-barnaaldern-1907.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_hilma-af-klint-svanen.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_the-mahatmas-present-standing-point-series-ii-no-2a-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_untitled(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/hilma-af-klint_wheat-and-wormwood-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_abstract-composition.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_baum-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_bild-no-131-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_bild-no-84-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_halraam-villa-wulffraat-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_kleurstudie-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacoba-van-heemskerck_natuurmotieven-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacques-villon_l-acrobate-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jacques-villon_untitled-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_blue-and-red-landscape-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919(4).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919(5).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919-1(5).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1919-5.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-1(8).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-5.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-6.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-7.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1920-8.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1921(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1921(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922(4).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922(5).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-1(9).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-10.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-11.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-5.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-6.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-7.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-8.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1922-9.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923(4).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923(5).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923(6).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-1(8).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-5.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-6.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-7.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-8.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_composition-1923-9.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_peaky-forms-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/janos-mattis-teutsch_red-landscape-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_abstract-composition.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_automatic-drawing.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_geometric-collage.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_geometric-forms.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_leafage-and-drops.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_relief-clock.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_squares-or-rectangles-arranged-according-to-laws-of-change-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_terrestrial-forest-form-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jean-arp_untitled.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_fantasy-in-equilibrium-1948.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_flood-tide-1957.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_fluctuating-planes-1952.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_from-a-riviera-window-1955.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_indian-myth-1948.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_legend-of-the-orient-1958.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_untitled-1946-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/jock-macdonald_untitled-1946.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/johannes-itten_die-begegnung-1916(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/johannes-itten_horizontal-vertical-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/johannes-itten_komposition-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/johannes-itten_linienrhythmus-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/johannes-itten_untitled-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/josef-albers_grid-mounted-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/joseph-stella_battle-of-lights-coney-island-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/joseph-stella_battle-of-lights-coney-island.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/joseph-stella_not-detected-276184.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/joseph-stella_not-detected-276185.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_astrazione-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_composizione-paesaggio-dada-n-3-o-n-2-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_five-o-clock-tea-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_fucina-studio-di-rumori-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_la-libra-s-infiamma-e-le-piramidi-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_paesaggio-interiore-apertura-del-diaframma-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_the-tendency-of-aesthetic-idealism-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_untitled-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/julius-evola_xilografia-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_1915-2.png
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_1923.png
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_1929.PNG
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_aeroplane-flying-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_black-circle-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_black-cross-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_black-cross-on-a-red-oval-1927.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_black-square-and-red-square-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_black-suprematistic-square-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_composition-1932.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_composition-with-a-black-circle-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_four-square-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_malevich-kazimir-severinovich-black-square-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_movement-suprematist-square-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_quadrilateral-and-the-circle-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_red-square-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_renewal-suprematist-square-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematic-compositional-elements-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematic-group-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematic-group-using-the-triangle-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematic-painting-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematic-painting-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematic-track-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-5.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-6.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-7.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915-8.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1916-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1916-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1916-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1927-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-1927.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-self-portrait-in-two-dimensions-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-two-dimensional-self-portrait-1915-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-two-dimensional-self-portrait-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-with-blue-triangle-and-black-square-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism-with-eight-rectangles-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematism.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematist-composition-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematist-painting-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematist-painting-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kazimir-malevich_suprematistic-construction-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_bathroom-in-the-morning-hanga-vol-13-1928.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_fairy-tale-of-the-sea-1949.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_form-no-3-uprise-of-blue-1948.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_light-time-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_lyric-no-9-distant-hope-1951.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_past.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_po-me-no-7-landscape-of-may-1948.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_poem-no-23-fish-1954.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/koshiro-onchi_poem-no-6-image-de-la-mer-1948.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_aphorism-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_construction-for-noble-ladies-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_difficult-1943.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_elikan-1925.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_forms-in-space-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_heavy-relief-1945.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_hitler-gang-1944.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_mai-191-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_merz-picture-25a-the-star-picture-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_merzbild-alf-1939.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_merzbild-rossfett-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_merzpicture-thirty-one-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_merzpicture-with-rainbow-1939.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_mz-231-miss-blanche-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_new-merzpicture-1931.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_oorlog-1930.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_picture-with-light-center-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_pino-antoni-1934.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_relief-in-relief-1945.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_revolving-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_santa-claus-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_small-sailors-home-1926.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_something-or-other-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_the-and-picture-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/kurt-schwitters_the-spring-door-1938.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/l-opold-survage_colored-rhythm-study-for-the-film-1913(30).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_composition-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_constructivist-composition-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_k-parchitekt-ra-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_pictorial-architecture-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_picturial-architecture-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_picturial-architecture-v-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_untitled-twenty-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lajos-kassak_wooden-relief-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_architectonic-painting.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_architectonics-in-painting-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_architectonics-in-painting.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_building-the-revolution-soviet-art-and-architecture.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_dramatic-architecture.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_lineare-composition.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_painterly-architectonic-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_painterly-architectonic-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_painterly-architectonic-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_painterly-architectonic.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_portrait.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_relief.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_space-force-construction-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_space-force-construction-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_space-force-construction-3.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_space-force-construction-4.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_space-force-construction.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_spatial-force-construction.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_still-life-with-instruments-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_untitled-compositions.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/lyubov-popova_untitled.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/m-h-maxy_vertical-construction-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/man-ray_jazz.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marcel-duchamp_disks-bearing-spirals-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marcel-duchamp_network-of-stoppages-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marcel-janco_euphoria-dada-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marcel-janco_troph-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marsden-hartley_abstraction-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marsden-hartley_painting-no-48-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marsden-hartley_painting-no-50-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/marsden-hartley_painting-number-5-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/max-weber_avoirdupois.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/max-weber_rush-hour.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/max-weber_slide-lecture-at-the-metropolitan-museum.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/mikhail-larionov_glass-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/mikhail-larionov_nocturne-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/mikhail-larionov_red-and-blue-rayonism-beach-1911.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_cosmic-synchromy-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_four-part-synchromy-number-7-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_synchromy-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_synchromy-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_synchromy-in-blue-violet-1912.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_synchromy-in-orange-to-form-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morgan-russell_synchromy-number-4-to-form-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_figure-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_machine-form-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_painting-formerly-machine-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_painting-iv-mechanical-abstraction-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_painting-vi-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_painting-vii-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_painting-viii-mechanical-abstraction-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/morton-shamberg_untitled-mechanical-abstraction-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/natalia-goncharova_cats-rayonist-perception-in-rose-black-and-yellow.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/natalia-goncharova_composition-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/natalia-goncharova_espagnole.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/natalia-goncharova_rayonist-lilies.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/oleksandr-bogomazov_abstract-composition-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/oleksandr-bogomazov_abstract-composition-2.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/oleksandr-bogomazov_abstract-composition.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/oleksandr-bogomazov_abstract-landscape-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/oleksandr-bogomazov_composition-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olexandr-archipenko_composition-1920.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_abstract-composition.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_blue-on-tin.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_collage-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_color-painting-non-objective-composition.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_directional-lines.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_flight-of-an-aeroplane-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_green-stripe-color-painting.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_non-objective-composition-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_non-objective-composition-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_non-objective-composition-suprematism-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_non-objective-composition-suprematism.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/olga-rozanova_suprematism-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_composition-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_composition-1931.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_composition-1936.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_composition-1938.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_composition-1940.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_gr-n-rot-1939.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_komposition-1940.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_komposition-in-schwarz-und-wei-1936.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_lichtkreise-kosmischer-regenbogen-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_rosace-ii-1941.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-freundlich_untitled-1938.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-gustav-carlsund_komposition-1926.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-gustav-carlsund_komposition-1931.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/otto-gustav-carlsund_konstruktion-1931.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/patrick-henry-bruce_composition-i-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/patrick-henry-bruce_composition-ii-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/patrick-henry-bruce_composition-iii-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/patrick-henry-bruce_composition-iv-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/patrick-henry-bruce_composition-v-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/patrick-henry-bruce_composition-vi-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_abstract-colour-harmony-in-squares-with-vermillion-accents-1924.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_abstraction-with-reference-to-a-flowering-tree-1925.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_add-in-red-1921(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_after-the-floods-1936(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_ancient-sound-abstract-on-black-background-1925.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_architecture-of-the-plain-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_asian-entertainers-1919(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_at-the-core-1935(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_cacodemonic-1916(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_castle-garden-1931(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_characters-in-yellow-1937(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_city-picture-with-red-and-green-accents-1921(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_colour-shapes-1914(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_coming-to-bloom-1934(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_cote-de-provence(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_crystal-1921(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_crystalline-landscape-1929.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_dream-city-1921(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_fire-evening-1929(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_flora-on-sand-1927(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_glass-facade-1940(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_halme-1940(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_hamamet-1914(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_hammamet(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_heroic-fiddling-1938(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_heroic-roses-1938(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_highway-and-byways-1929(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_in-the-current-six-thresholds-1929(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_in-the-style-of-kairouan-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_individualized-altimetry-of-stripes-1930.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_insula-dulcamara-1921(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_legend-of-the-nile-1937(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_main-path-and-byways-1929(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_monument-1929(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_mountain-village-autumnal-1934(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_necropolis-1929.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_new-harmony-1936.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_red-waistcoat-1938(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_refuge-1930(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_rhythmic-rythmical-1930(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_rock-chamber-1929.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_separation-in-the-evening-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_side-panels-for-anatomy-of-aphrodite-1915(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_southern-tunisian-gardens-1919(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_structural-ii-1924(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_the-column-1926(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_the-messenger-of-autumn-1922(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_the-place-of-the-twins-1929(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_the-rumors-1939(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_transparent-in-perspective-grooved-1921(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_with-the-egg-1917(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-klee_woman-in-peasant-dress-1940(1).jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/paul-nash_in-the-marshes-38.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/pavel-filonov_a-white-picture-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/pavel-filonov_composition-1929-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/pavel-filonov_composition-1929.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/peter-laszlo-peri_fullsizerender.jpeg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/peter-laszlo-peri_img-5207.jpeg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/peter-laszlo-peri_img-5209.jpeg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/peter-laszlo-peri_space-construction-10-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/peter-laszlo-peri_space-construction-vi-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_broadway-boogie-woogie-1943.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-2-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-a-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-c-no-iii-with-red-yellow-and-blue-1935.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-iii-with-blue-yellow-and-white-1936.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-in-color-a-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-n-11-london-with-blue-red-and-yellow.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-n-i-with-red-and-blue-1931.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-no-10-1942.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-no-iii-blanc-jaune-1942.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-blue-1937.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-gray-and-light-brown-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-grid-ix-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-grid-vii-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-large-red-plane-yellow-black-gray-and-blue-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-oval-in-color-planes-ii-1914.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-red-blue-and-yellow-1930.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-red-yellow-and-blue-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-red-yellow-and-blue-1942.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_composition-with-yellow-patch-1930.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_lozenge-composition-3-lines-blue-gray-yellow.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_lozenge-composition-with-red-black-blue-and-yellow-1925.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_lozenge-composition-with-red-gray-blue-yellow-and-black-1925.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_new-york-city-i-1942.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_not-identified.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_picture-no-iii.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_pit-mondrijan-kompozitsija-ii-1929.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_place-de-la-concorde-1943.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_tableau-3-with-orange-red-yellow-black-blue-and-gray.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_tableau-i-1921.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_trafalgar-square-1943.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_vertical-composition-with-blue-and-white-1936.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/piet-mondrian_victory-boogie-woogie-1944.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_circular-forms.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_ciudades-city.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_color-explosion.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_homage-to-bleriot.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_premier-disque.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_rhythm-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_rhythm-color.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_rhythm.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_rythm-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_rythm.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_simultaneous-windows-2nd-motif-1st-part.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_the-joy-of-life.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_window.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/robert-delaunay_windows-open-simultaneously-1st-part-3rd-motif.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/rudolf-bauer_con-roso-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/rudolf-bauer_lines-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/rudolf-bauer_sinfonie-xiii-1913.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/rudolf-bauer_untitled-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sonia-delaunay_electric-prisms-1.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sonia-delaunay_portuguese-market-1915.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_composition-1937.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_composition-dans-un-cercle-1937.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_composition-of-circles-and-overlapping-angles-1930.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_echelonnement-desaxe-1934.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_elementary-forms-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_figures-1926.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_oval-composition-with-abstract-motifs-1922.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_relief-rectangulaire.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_rising-falling-flying-1934.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_untitled-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_vertical-and-horizontal-composition-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/sophie-taeuber-arp_vertical-and-horizontal-composition-1928.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_architectural-analysis-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_arithmetic-composition-1929.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-1917.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-1918.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-1923.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-1928.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-1931.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-i-still-life-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-ii-still-life-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-in-gray-rag-time-1919.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-iv-still-life-1916.jpg
#   inflating: /content/drive/MyDrive/Dataset/abstract-art/theo-van-doesburg_composition-ix-opus-18-1917-1917.jpg
# ...
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000825.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000825_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000825_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000826.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000826_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000826_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000827.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000827_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000827_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000828.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000828_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000828_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000829.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000829_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000829_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000830.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000830_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000830_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000831.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000831_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000831_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000832.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000832_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000832_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000833.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000833_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000833_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000834.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000834_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000834_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000835.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000835_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000835_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000836.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000836_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000836_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000837.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000837_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000837_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000838.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000838_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000838_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000839.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000839_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000839_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000840.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000840_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000840_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000841.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000841_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000841_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000842.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000842_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000842_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000843.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000843_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000843_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000844.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000844_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000844_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000845.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000845_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000845_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000846.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000846_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000846_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000847.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000847_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000847_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000848.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000848_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000848_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000849.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000849_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000849_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000850.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000850_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000850_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000851.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000851_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000851_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000852.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000852_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000852_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000853.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000853_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000853_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000854.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000854_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000854_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000855.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000855_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000855_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000856.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000856_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000856_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000857.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000857_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000857_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000858.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000858_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000858_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000859.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000859_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000859_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000860.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000860_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000860_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000861.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000861_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000861_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000862.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000862_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000862_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000863.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000863_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000863_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000864.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000864_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000864_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000865.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000865_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000865_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000866.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000866_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000866_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000867.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000867_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000867_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000868.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000868_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000868_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000869.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000869_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000869_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000870.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000870_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000870_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000871.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000871_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000871_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000872.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000872_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000872_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000873.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000873_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000873_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000874.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000874_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000874_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000875.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000875_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000875_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000876.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000876_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000876_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000877.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000877_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000877_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000878.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000878_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000878_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000879.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000879_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000879_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000880.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000880_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000880_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000881.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000881_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000881_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000882.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000882_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000882_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000883.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000883_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000883_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000884.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000884_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000884_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000885.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000885_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000885_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000886.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000886_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000886_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000887.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000887_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000887_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000888.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000888_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000888_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000889.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000889_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000889_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000890.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000890_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000890_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000891.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000891_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000891_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000892.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000892_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000892_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000893.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000893_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000893_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000894.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000894_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000894_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000895.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000895_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000895_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000896.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000896_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000896_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000897.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000897_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000897_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000898.jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000898_(2).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/00000898_(3).jpg
#   inflating: /content/drive/MyDrive/Dataset/landscape/17113423899_014f7a2b02_k.jpg

# %%
# Landscape dataset Preprocessing Images to 1024x1024

# %% [markdown]
# ## Convert dataset to .tfrecords

# %% [markdown]
# **Note: You only need to do this once per dataset. If you have already run this and are returning to conntinue training, skip these cells.**
#
# Next we need to convert our image dataset to a format that StyleGAN2-ADA can read from. There are two options here. You can upload your dataset directly to Colab (as a zipped file), or you can upload it to Drive directly and read it from there.

# %% [markdown]
# Now that your image dataset is uploaded, we need to convert it to the `.tfrecords` format.
#
# Depending on the resolution of your images and how many you have, this can take a while.

# %%
# %cd /content/drive/MyDrive/colab-sg2-ada/stylegan2-ada
#update this to the path to your image folder
dataset_path = "/content/drive/MyDrive/Dataset/abstract-art"
#give your dataset a name
dataset_name = "abstract-art"

#you don't need to edit anything here
# !python dataset_tool.py create_from_images ./datasets/{dataset_name} {dataset_path}
# Out:
# /content/drive/MyDrive/colab-sg2-ada/stylegan2-ada
# Loading images from "/content/drive/MyDrive/Dataset/abstract-art"
# Creating dataset "./datasets/abstract-art"
# dataset_tool.py:97: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   'data': tf.train.Feature(bytes_list=tf.train.BytesList(value=[quant.tostring()]))}))
# Added 850 images.

# %% [markdown]
# ## Train a custom model
#
# We’re ready to start training! There are numerous arguments to training, what’s listed below are the most popular options. To see all the options, run the following cell.

# %%
# Use them only for metrics and help with the arguments
# This is just some help arguments
# !python train.py --help
# Out:
# usage: train.py [-h] --outdir DIR [--gpus INT] [--snap INT] [--seed INT] [-n]
#                 --data PATH [--res INT] [--mirror BOOL] [--mirrory BOOL]
#                 [--use-raw BOOL] [--metrics LIST] [--metricdata PATH]
#                 [--cfg {auto,11gb-gpu,11gb-gpu-complex,24gb-gpu,24gb-gpu-complex,48gb-gpu,48gb-2gpu,stylegan2,paper256,paper512,paper1024,cifar,cifarbaseline,aydao}]
#                 [--lrate FLOAT] [--ttur BOOL] [--gamma FLOAT] [--nkimg INT]
#                 [--kimg INT] [--topk FLOAT] [--aug {noaug,ada,fixed,adarv}]
#                 [--p FLOAT] [--target TARGET] [--initstrength INITSTRENGTH]
#                 [--augpipe {blit,geom,color,filter,noise,cutout,bg,bgc,bgcf,bgcfn,bgcfnc}]
#                 [--cmethod {nocmethod,bcr,zcr,pagan,wgangp,auxrot,spectralnorm,shallowmap,adropout}]
#                 [--dcap FLOAT] [--resume RESUME] [--freezed INT]
#
# Train a GAN using the techniques described in the paper
# "Training Generative Adversarial Networks with Limited Data".
#
# optional arguments:
#   -h, --help            show this help message and exit
#
# general options:
#   --outdir DIR          Where to save the results (required)
#   --gpus INT            Number of GPUs to use (default: 1 gpu)
#   --snap INT            Snapshot interval (default: 50 ticks)
#   --seed INT            Random seed (default: 1000)
#   -n, --dry-run         Print training options and exit
#
# training dataset:
#   --data PATH           Training dataset path (required)
#   --res INT             Dataset resolution (default: highest available)
#   --mirror BOOL         Augment dataset with x-flips (default: false)
#   --mirrory BOOL        Augment dataset with y-flips (default: false)
#   --use-raw BOOL        Use raw image dataset, i.e. created from
#                         create_from_images_raw (default: False)
#
# metrics:
#   --metrics LIST        Comma-separated list or "none" (default: fid50k_full)
#   --metricdata PATH     Dataset to evaluate metrics against (optional)
#
# base config:
#   --cfg {auto,11gb-gpu,11gb-gpu-complex,24gb-gpu,24gb-gpu-complex,48gb-gpu,48gb-2gpu,stylegan2,paper256,paper512,paper1024,cifar,cifarbaseline,aydao}
#                         Base config (default: auto)
#   --lrate FLOAT         Override learning rate
#   --ttur BOOL           Use Two Time-Scale Update Rule (double learning rate
#                         for discriminator) (default: false)
#   --gamma FLOAT         Override R1 gamma
#   --nkimg INT           Override starting count
#   --kimg INT            Override training duration
#   --topk FLOAT          utilize top-k training
#
# discriminator augmentation:
#   --aug {noaug,ada,fixed,adarv}
#                         Augmentation mode (default: ada)
#   --p FLOAT             Specify augmentation probability for --aug=fixed
#   --target TARGET       Override ADA target for --aug=ada and --aug=adarv
#   --initstrength INITSTRENGTH
#                         Override ADA strength at start
#   --augpipe {blit,geom,color,filter,noise,cutout,bg,bgc,bgcf,bgcfn,bgcfnc}
#                         Augmentation pipeline (default: bgc)
#
# comparison methods:
#   --cmethod {nocmethod,bcr,zcr,pagan,wgangp,auxrot,spectralnorm,shallowmap,adropout}
#                         Comparison method (default: nocmethod)
#   --dcap FLOAT          Multiplier for discriminator capacity
#
# transfer learning:
#   --resume RESUME       Resume from network pickle (default: noresume)
#   --freezed INT         Freeze-D (default: 0 discriminator layers)
#
# examples:
#
#   # Train custom dataset using 1 GPU.
#   python train.py --outdir=~/training-runs --gpus=1 --data=~/datasets/custom
#
#   # Train class-conditional CIFAR-10 using 2 GPUs.
#   python train.py --outdir=~/training-runs --gpus=2 --data=~/datasets/cifar10c \
#       --cfg=cifar
#
#   # Transfer learn MetFaces from FFHQ using 4 GPUs.
#   python train.py --outdir=~/training-runs --gpus=4 --data=~/datasets/metfaces \
#       --cfg=paper1024 --mirror=1 --resume=ffhq1024 --snap=10
#
#   # Reproduce original StyleGAN2 config F.
#   python train.py --outdir=~/training-runs --gpus=8 --data=~/datasets/ffhq \
#       --cfg=stylegan2 --res=1024 --mirror=1 --aug=noaug
#
# available base configs (--cfg):
#   auto           Automatically select reasonable defaults based on resolution
#                  and GPU count. Good starting point for new datasets.
#   stylegan2      Reproduce results for StyleGAN2 config F at 1024x1024.
#   paper256       Reproduce results for FFHQ and LSUN Cat at 256x256.
#   paper512       Reproduce results for BreCaHAD and AFHQ at 512x512.
#   paper1024      Reproduce results for MetFaces at 1024x1024.
#   cifar          Reproduce results for CIFAR-10 (tuned configuration).
#   cifarbaseline  Reproduce results for CIFAR-10 (baseline configuration).
#
# transfer learning source networks (--resume):
#   ffhq256        FFHQ trained at 256x256 resolution.
#   ffhq512        FFHQ trained at 512x512 resolution.
#   ffhq1024       FFHQ trained at 1024x1024 resolution.
#   celebahq256    CelebA-HQ trained at 256x256 resolution.
#   lsundog256     LSUN Dog trained at 256x256 resolution.
#   afhqcat512     AFHQ Cat trained at 512x512 resolution.
#   afhqdog512     AFHQ Dog trained at 512x512 resolution.
#   afhqwild512    AFHQ Wild trained at 512x512 resolution.
#   brecahad512    BreCaHAD trained at 512x512 resolution.
#   cifar10        CIFAR10 trained at 32x32 resolution.
#   metfaces512    MetFaces trained at 512x512 resolution.
#   <path or URL>  Custom network pickle.

# %%
#this name must EXACTLY match the dataset name you used when creating the .tfrecords file
dataset_name = "robgon-abstract"
#how often should the model generate samples and a .pkl file
snapshot_count = 4
#should the images be mirrored left to right?
mirrored = True
#should the images be mirrored top to bottom?
mirroredY = True
#metrics? 
metric_list = None
#augments
augs = "bg"

#
# this is the most important cell to update
#
# running it for the first time? set it to ffhq(+resolution)
# resuming? get the path to your latest .pkl file and use that
resume_from = "/content/drive/My\ Drive/colab-sg2-ada2/stylegan2-ada/results/00008-dante1024-mirror-mirrory-11gb-gpu-bg-resumecustom/network-snapshot-000160.pkl"

#don't edit this unless you know what you're doing :)
# !python train.py --outdir ./results --snap={snapshot_count} --cfg=11gb-gpu --data=./datasets/{dataset_name} --augpipe={augs} --mirror={mirrored} --mirrory={mirroredY} --metrics={metric_list} --resume={resume_from} --augpipe="bg"

# %% [markdown]
# ### While it’s training...
# **Once the above cell is running you should be training!**
#
# Don’t close this tab! Colab needs to be open and running in order to continue training. Every ~15min or so a new line should get added to your output, indicated its still training. Depending on you `snapshot_count` setting you should see the results folder in your Google drive folder fill with both samples (`fakesXXXXXx.jpg`) and model weights (`network-snapshot-XXXXXX.pkl`). The samples are worth looking at while it trains but don’t get too worried about each individual sample.
#
# If you chose a metric, you will also see scores for each snapshot. Don’t obsess over these! they are a guide, it can go up or down slightly for each snapshot. What you want to see is a gradual lowering of the score over time.
#
# Once Colab shuts off, you can Reconnect the notebook and re-run every cell from top to bottom. Make sure you update the `resume_from` path to continue training from the latest model.

# %% [markdown]
# ## Training model from scratch

# %%
#this name must EXACTLY match the dataset name you used when creating the .tfrecords file
dataset_name = "robgon-abstract"
#how often should the model generate samples and a .pkl file
snapshot_count = 4
#should the images be mirrored left to right?
mirrored = True
#should the images be mirrored top to bottom?
mirroredY = True
#metrics? 
metric_list = None
#augments
augs = "bg"

#
# this is the most important cell to update
#
# running it for the first time? set it to ffhq(+resolution)

#don't edit this unless you know what you're doing :)
# !python train.py --outdir ./results --snap={snapshot_count} --cfg=auto --data=./datasets/{dataset_name} --augpipe={augs} --mirror={mirrored} --mirrory={mirroredY} --metrics={metric_list} --augpipe="bg"
# Out:
# tcmalloc: large alloc 4294967296 bytes == 0x559d90e62000 @  0x7f1461ba5001 0x7f145eda854f 0x7f145edf8b58 0x7f145edfcb17 0x7f145ee9b203 0x559d89d5d544 0x559d89d5d240 0x559d89dd1627 0x559d89dcbced 0x559d89d5f48c 0x559d89da0159 0x559d89d9d0a4 0x559d89d5dd49 0x559d89dd194f 0x559d89dcb9ee 0x559d89c9de2b 0x559d89dcdfe4 0x559d89dcb9ee 0x559d89c9de2b 0x559d89dcdfe4 0x559d89dcbced 0x559d89c9de2b 0x559d89dcdfe4 0x559d89d5eafa 0x559d89dcc915 0x559d89dcb9ee 0x559d89dcb6f3 0x559d89e954c2 0x559d89e9583d 0x559d89e956e6 0x559d89e6d163
# tcmalloc: large alloc 4294967296 bytes == 0x559e90e62000 @  0x7f1461ba31e7 0x7f145eda846e 0x7f145edf8c7b 0x7f145edf935f 0x7f145ee9b103 0x559d89d5d544 0x559d89d5d240 0x559d89dd1627 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89d5eafa 0x559d89dcc915 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dd0d00 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89dcbced 0x559d89d5f48c 0x559d89da0159 0x559d89d9d0a4 0x559d89d5dd49 0x559d89dd194f
# tcmalloc: large alloc 4294967296 bytes == 0x559f91fa6000 @  0x7f1461ba31e7 0x7f145eda846e 0x7f145edf8c7b 0x7f145edf935f 0x7f141b7aa235 0x7f141b12d792 0x7f141b12dd42 0x7f141b0e6aee 0x559d89d5d437 0x559d89d5d240 0x559d89dd10f3 0x559d89d5eafa 0x559d89dccc0d 0x559d89dcbced 0x559d89c9deb0 0x559d89dcdfe4 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dccc0d 0x559d89dcbced 0x559d89d5ebda 0x559d89dccc0d 0x559d89d5eafa 0x559d89dccc0d 0x559d89dcb9ee 0x559d89d5f271 0x559d89d5f698 0x559d89dcdfe4 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcc915
#
# Training options:
# {
#   "G_args": {
#     "func_name": "training.networks.G_main",
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "mapping_layers": 2,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "D_args": {
#     "func_name": "training.networks.D_main",
#     "mbstd_group_size": 4,
#     "fmap_base": 16384,
#     "fmap_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.002
#   },
#   "D_opt_args": {
#     "beta1": 0.0,
#     "beta2": 0.99,
#     "learning_rate": 0.002
#   },
#   "loss_args": {
#     "func_name": "training.loss.stylegan2",
#     "r1_gamma": 52.4288
#   },
#   "augment_args": {
#     "class_name": "training.augment.AdaptiveAugment",
#     "tune_heuristic": "rt",
#     "tune_target": 0.6,
#     "apply_func": "training.augment.augment_pipeline",
#     "apply_args": {
#       "xflip": 1,
#       "rotate90": 1,
#       "xint": 1,
#       "scale": 1,
#       "rotate": 1,
#       "aniso": 1,
#       "xfrac": 1
#     }
#   },
#   "num_gpus": 1,
#   "image_snapshot_ticks": 4,
#   "network_snapshot_ticks": 4,
#   "train_dataset_args": {
#     "path": "./datasets/robgon-abstract",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 1024,
#     "mirror_augment": true,
#     "mirror_augment_v": true
#   },
#   "metric_arg_list": [],
#   "metric_dataset_args": {
#     "path": "./datasets/robgon-abstract",
#     "max_label_size": 0,
#     "use_raw": false,
#     "resolution": 1024,
#     "mirror_augment": true,
#     "mirror_augment_v": true
#   },
#   "total_kimg": 25000,
#   "minibatch_size": 4,
#   "minibatch_gpu": 4,
#   "G_smoothing_kimg": 1.25,
#   "G_smoothing_rampup": 0.05,
#   "run_dir": "./results/00000-robgon-abstract-mirror-mirrory-auto1-bg"
# }
#
# Output directory:  ./results/00000-robgon-abstract-mirror-mirrory-auto1-bg
# Training data:     ./datasets/robgon-abstract
# Training length:   25000 kimg
# Resolution:        1024
# Number of GPUs:    1
#
# Creating output directory...
# Loading training set...
# tcmalloc: large alloc 4294967296 bytes == 0x559d90b60000 @  0x7f1461ba5001 0x7f145eda854f 0x7f145edf8b58 0x7f145edfcb17 0x7f145ee9b203 0x559d89d5d544 0x559d89d5d240 0x559d89dd1627 0x559d89dcbced 0x559d89d5f48c 0x559d89da0159 0x559d89d9d0a4 0x559d89d5dd49 0x559d89dd194f 0x559d89dcb9ee 0x559d89c9de2b 0x559d89dcdfe4 0x559d89dcb9ee 0x559d89c9de2b 0x559d89dcdfe4 0x559d89dcbced 0x559d89c9de2b 0x559d89dcdfe4 0x559d89d5eafa 0x559d89dcc915 0x559d89dcb9ee 0x559d89dcb6f3 0x559d89e954c2 0x559d89e9583d 0x559d89e956e6 0x559d89e6d163
# tcmalloc: large alloc 4294967296 bytes == 0x55a091fa6000 @  0x7f1461ba31e7 0x7f145eda846e 0x7f145edf8c7b 0x7f145edf935f 0x7f145ee9b103 0x559d89d5d544 0x559d89d5d240 0x559d89dd1627 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89d5eafa 0x559d89dcc915 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dd0d00 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcd737 0x559d89dcbced 0x559d89d5f48c 0x559d89da0159 0x559d89d9d0a4 0x559d89d5dd49 0x559d89dd194f
# tcmalloc: large alloc 4294967296 bytes == 0x55a091fa6000 @  0x7f1461ba31e7 0x7f145eda846e 0x7f145edf8c7b 0x7f145edf935f 0x7f141b7aa235 0x7f141b12d792 0x7f141b12dd42 0x7f141b0e6aee 0x559d89d5d437 0x559d89d5d240 0x559d89dd10f3 0x559d89d5eafa 0x559d89dccc0d 0x559d89dcbced 0x559d89c9deb0 0x559d89dcdfe4 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dccc0d 0x559d89dcbced 0x559d89d5ebda 0x559d89dccc0d 0x559d89d5eafa 0x559d89dccc0d 0x559d89dcb9ee 0x559d89d5f271 0x559d89d5f698 0x559d89dcdfe4 0x559d89dcb9ee 0x559d89d5ebda 0x559d89dcc915
# Image shape: [3, 1024, 1024]
# Label shape: [0]
#
# Constructing networks...
# Setting up TensorFlow plugin "fused_bias_act.cu": Compiling... Loading... Done.
# Setting up TensorFlow plugin "upfirdn_2d.cu": Compiling... Loading... Done.
#
# G                               Params    OutputShape          WeightShape
# ---                             ---       ---                  ---
# latents_in                      -         (?, 512)             -
# labels_in                       -         (?, 0)               -
# epochs                          1         ()                   ()
# epochs_1                        1         ()                   ()
# G_mapping/Normalize             -         (?, 512)             -
# G_mapping/Dense0                262656    (?, 512)             (512, 512)
# G_mapping/Dense1                262656    (?, 512)             (512, 512)
# G_mapping/Broadcast             -         (?, 18, 512)         -
# dlatent_avg                     -         (512,)               -
# Truncation/Lerp                 -         (?, 18, 512)         -
# G_synthesis/4x4/Const           8192      (?, 512, 4, 4)       (1, 512, 4, 4)
# G_synthesis/4x4/Conv            2622465   (?, 512, 4, 4)       (3, 3, 512, 512)
# G_synthesis/4x4/ToRGB           264195    (?, 3, 4, 4)         (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up        2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Conv1           2622465   (?, 512, 8, 8)       (3, 3, 512, 512)
# G_synthesis/8x8/Upsample        -         (?, 3, 8, 8)         -
# G_synthesis/8x8/ToRGB           264195    (?, 3, 8, 8)         (1, 1, 512, 3)
# G_synthesis/16x16/Conv0_up      2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Conv1         2622465   (?, 512, 16, 16)     (3, 3, 512, 512)
# G_synthesis/16x16/Upsample      -         (?, 3, 16, 16)       -
# G_synthesis/16x16/ToRGB         264195    (?, 3, 16, 16)       (1, 1, 512, 3)
# G_synthesis/32x32/Conv0_up      2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Conv1         2622465   (?, 512, 32, 32)     (3, 3, 512, 512)
# G_synthesis/32x32/Upsample      -         (?, 3, 32, 32)       -
# G_synthesis/32x32/ToRGB         264195    (?, 3, 32, 32)       (1, 1, 512, 3)
# G_synthesis/64x64/Conv0_up      2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Conv1         2622465   (?, 512, 64, 64)     (3, 3, 512, 512)
# G_synthesis/64x64/Upsample      -         (?, 3, 64, 64)       -
# G_synthesis/64x64/ToRGB         264195    (?, 3, 64, 64)       (1, 1, 512, 3)
# G_synthesis/128x128/Conv0_up    1442561   (?, 256, 128, 128)   (3, 3, 512, 256)
# G_synthesis/128x128/Conv1       721409    (?, 256, 128, 128)   (3, 3, 256, 256)
# G_synthesis/128x128/Upsample    -         (?, 3, 128, 128)     -
# G_synthesis/128x128/ToRGB       132099    (?, 3, 128, 128)     (1, 1, 256, 3)
# G_synthesis/256x256/Conv0_up    426369    (?, 128, 256, 256)   (3, 3, 256, 128)
# G_synthesis/256x256/Conv1       213249    (?, 128, 256, 256)   (3, 3, 128, 128)
# G_synthesis/256x256/Upsample    -         (?, 3, 256, 256)     -
# G_synthesis/256x256/ToRGB       66051     (?, 3, 256, 256)     (1, 1, 128, 3)
# G_synthesis/512x512/Conv0_up    139457    (?, 64, 512, 512)    (3, 3, 128, 64)
# G_synthesis/512x512/Conv1       69761     (?, 64, 512, 512)    (3, 3, 64, 64)
# G_synthesis/512x512/Upsample    -         (?, 3, 512, 512)     -
# G_synthesis/512x512/ToRGB       33027     (?, 3, 512, 512)     (1, 1, 64, 3)
# G_synthesis/1024x1024/Conv0_up  51297     (?, 32, 1024, 1024)  (3, 3, 64, 32)
# G_synthesis/1024x1024/Conv1     25665     (?, 32, 1024, 1024)  (3, 3, 32, 32)
# G_synthesis/1024x1024/Upsample  -         (?, 3, 1024, 1024)   -
# G_synthesis/1024x1024/ToRGB     16515     (?, 3, 1024, 1024)   (1, 1, 32, 3)
# ---                             ---       ---                  ---
# Total                           28794126
#
#
# D                     Params    OutputShape          WeightShape
# ---                   ---       ---                  ---
# images_in             -         (?, 3, 1024, 1024)   -
# labels_in             -         (?, 0)               -
# 1024x1024/FromRGB     128       (?, 32, 1024, 1024)  (1, 1, 3, 32)
# 1024x1024/Conv0       9248      (?, 32, 1024, 1024)  (3, 3, 32, 32)
# 1024x1024/Conv1_down  18496     (?, 64, 512, 512)    (3, 3, 32, 64)
# 1024x1024/Skip        2048      (?, 64, 512, 512)    (1, 1, 32, 64)
# 512x512/Conv0         36928     (?, 64, 512, 512)    (3, 3, 64, 64)
# 512x512/Conv1_down    73856     (?, 128, 256, 256)   (3, 3, 64, 128)
# 512x512/Skip          8192      (?, 128, 256, 256)   (1, 1, 64, 128)
# 256x256/Conv0         147584    (?, 128, 256, 256)   (3, 3, 128, 128)
# 256x256/Conv1_down    295168    (?, 256, 128, 128)   (3, 3, 128, 256)
# 256x256/Skip          32768     (?, 256, 128, 128)   (1, 1, 128, 256)
# 128x128/Conv0         590080    (?, 256, 128, 128)   (3, 3, 256, 256)
# 128x128/Conv1_down    1180160   (?, 512, 64, 64)     (3, 3, 256, 512)
# 128x128/Skip          131072    (?, 512, 64, 64)     (1, 1, 256, 512)
# 64x64/Conv0           2359808   (?, 512, 64, 64)     (3, 3, 512, 512)
# 64x64/Conv1_down      2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 64x64/Skip            262144    (?, 512, 32, 32)     (1, 1, 512, 512)
# 32x32/Conv0           2359808   (?, 512, 32, 32)     (3, 3, 512, 512)
# 32x32/Conv1_down      2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 32x32/Skip            262144    (?, 512, 16, 16)     (1, 1, 512, 512)
# 16x16/Conv0           2359808   (?, 512, 16, 16)     (3, 3, 512, 512)
# 16x16/Conv1_down      2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 16x16/Skip            262144    (?, 512, 8, 8)       (1, 1, 512, 512)
# 8x8/Conv0             2359808   (?, 512, 8, 8)       (3, 3, 512, 512)
# 8x8/Conv1_down        2359808   (?, 512, 4, 4)       (3, 3, 512, 512)
# 8x8/Skip              262144    (?, 512, 4, 4)       (1, 1, 512, 512)
# 4x4/MinibatchStddev   -         (?, 513, 4, 4)       -
# 4x4/Conv              2364416   (?, 512, 4, 4)       (3, 3, 513, 512)
# 4x4/Dense0            4194816   (?, 512)             (8192, 512)
# Output                513       (?, 1)               (512, 1)
# ---                   ---       ---                  ---
# Total                 29012513
#
# Exporting sample images...
# 2021-10-23 09:52:13.838680: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 88080384 exceeds 10% of system memory.
# Replicating networks across 1 GPUs...
# Initializing augmentations...
# Setting up optimizers...
# Constructing training graph...
# Finalizing training ops...
# 2021-10-23 09:53:12.741238: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 16777216 exceeds 10% of system memory.
# 2021-10-23 09:53:12.753564: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 16777216 exceeds 10% of system memory.
# 2021-10-23 09:53:12.807055: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 16777216 exceeds 10% of system memory.
# 2021-10-23 09:53:12.814472: W tensorflow/core/framework/cpu_allocator_impl.cc:81] Allocation of 16777216 exceeds 10% of system memory.
# Initializing metrics...
# Training for 25000 kimg...
#
# 2021-10-23 09:55:01.000287: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:55:08.392291: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:55:15.952189: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# tick 0     kimg 0.0      time 4m 59s       sec/tick 119.3   sec/kimg 7456.98 maintenance 179.9  gpumem 10.3  augment 0.000
# 2021-10-23 09:55:48.350694: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:55:57.713979: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:56:05.163654: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:56:12.545890: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:56:19.905419: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:56:29.302861: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2021-10-23 09:56:36.685429: W tensorflow/core/common_runtime/bfc_allocator.cc:239] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.25GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.

# %% [markdown]
# # Part 2 Generating AI Art

# %% [markdown]
# ### **Setup**

# %% [markdown]
# #### Install Repo to Google Drive
#
# Colab is a little funky with training. I’ve found the best way to do this is to install the repo directly into your Google Drive folder. This will save the training if it crashes.
#
# First, mount your Drive to the Colab notebook:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### Installing Libraries
# Next, run the cell below. If you’re already installed the repo, it will skip the installation process and change into the repo’s directory. If you haven’t installed it, it will install all the libraries necessary.

# %%
import os
if os.path.isdir("/content/drive/MyDrive/py-sg2-ada"):
    # !mkdir dataset
    # %cd "/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch"
    # !pip install torch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2 
    # !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
    # !pip install opensimplex
    
else:
    #install script
    # !mkdir dataset
    # %cd "/content/drive/My Drive/"
    # !mkdir py-sg2-ada
    # %cd py-sg2-ada
    # !git clone https://github.com/NVlabs/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir datasets
    # !mkdir output
    # !pip install torch==1.7.1 torchvision==0.8.2 torchaudio==0.7.2
    # !pip install click requests tqdm pyspng ninja imageio-ffmpeg==0.4.3
    # !pip install opensimplex
# Out:
# /content/drive/My Drive
# /content/drive/My Drive/py-sg2-ada
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 125 (delta 45), reused 39 (delta 39), pack-reused 47
# Receiving objects: 100% (125/125), 1.12 MiB | 5.59 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# /content/drive/My Drive/py-sg2-ada/stylegan2-ada-pytorch
# Collecting torch==1.7.1
#   Downloading torch-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (776.8 MB)
#      |████████████████████████████████| 776.8 MB 16 kB/s
# Collecting torchvision==0.8.2
#   Downloading torchvision-0.8.2-cp37-cp37m-manylinux1_x86_64.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 55.8 MB/s
# Collecting torchaudio==0.7.2
#   Downloading torchaudio-0.7.2-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 55.6 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.7.1) (3.7.4.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.7/dist-packages (from torchvision==0.8.2) (7.1.2)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.9.0+cu111
#     Uninstalling torch-1.9.0+cu111:
#       Successfully uninstalled torch-1.9.0+cu111
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.10.0+cu111
#     Uninstalling torchvision-0.10.0+cu111:
#       Successfully uninstalled torchvision-0.10.0+cu111
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.7.1 which is incompatible.
# Successfully installed torch-1.7.1 torchaudio-0.7.2 torchvision-0.8.2
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.62.3)
# Collecting pyspng
#   Downloading pyspng-0.1.0-cp37-cp37m-manylinux2010_x86_64.whl (195 kB)
#      |████████████████████████████████| 195 kB 4.0 MB/s
# Collecting ninja
#   Downloading ninja-1.10.2.2-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 60.4 MB/s
# Collecting imageio-ffmpeg==0.4.3
#   Downloading imageio_ffmpeg-0.4.3-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#      |████████████████████████████████| 26.9 MB 184 kB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyspng) (1.19.5)
# Installing collected packages: pyspng, ninja, imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.4.3 ninja-1.10.2.2 pyspng-0.1.0
# Collecting opensimplex
#   Downloading opensimplex-0.3-py3-none-any.whl (15 kB)
# Installing collected packages: opensimplex
# Successfully installed opensimplex-0.3

# %% [markdown]
# ### **Processing Custom Dataset**

# %% [markdown]
# Upload your custom zipped dataset to the "datasets" folder in the py-sg2-ada folder, and then copy the path into the below code.

# %%
your_dataset_path = "/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/dataset.zip"

# %%
# !python dataset_tool.py --source {your_dataset_path} --dest /content/dataset --transform=center-crop-wide --width 1024 --height 1024

# %% [markdown]
# #### Pre-Processed Dataset Preped
# Don't have a dataset? You can use one by genre using the dropdown menu. If you have one already, skip this.

# %%
#@title Choose Your Dataset

Dataset = 'Abstract_Expressionism' #@param ["Abstract_Expressionism", "Art_Nouveau_Modern", "Baroque", "Color_Field_Painting", "Cubism", "Expressionism", "Fauvism", "High_Renaissance", "Impressionism", "Mannerism_Late_Renaissance", "Minimalism", "Naive_Art_Primitivism", "Northern_Renaissance", "pop_art", "Post_Impressionism", "Realism", "Rococo", "Romanticism", "Symbolism", "Ukiyo_e"]
# %cd "/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets"

if Dataset is 'Minimalism':
  # !wget https://archive.org/download/StyleGANDatasets/Minimalism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Minimalism.zip' -d /content/
  dataset_path= "/content/Minimalism"

if Dataset is "Cubism":
  # !wget https://archive.org/download/StyleGANDatasets/Cubism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Cubism.zip' -d /content/
  dataset_path= "/content/Cubism" 

if Dataset is "Abstract_Expressionism":
  # !wget https://archive.org/download/StyleGANDatasets/Abstract_Expressionism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Abstract_Expressionism.zip' -d /content/
  dataset_path= "/content/Abstract_Expressionism"

if Dataset is "Color_Field_Painting":
  # !wget https://archive.org/download/StyleGANDatasets/Color_Field_Painting.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Color_Field_Painting.zip' -d /content/
  dataset_path= "/content/Color_Field_Painting"
 
if Dataset is "Fauvism":
  # !wget https://archive.org/download/StyleGANDatasets/Fauvism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Fauvism.zip' -d /content/
  dataset_path= "/content/Fauvism"

if Dataset is "High_Renaissance":
  # !wget https://archive.org/download/StyleGANDatasets/High_Renaissance.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/High_Renaissance.zip' -d /content/
  dataset_path= "/content/High_Renaissance"

if Dataset is "Mannerism_Late_Renaissance": 
  # !wget https://archive.org/download/StyleGANDatasets/Mannerism_Late_Renaissance.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Mannerism_Late_Renaissance.zip' -d /content/
  dataset_path= "/content/Mannerism_Late_Renaissance"

if Dataset is "Rococo":
  # !wget https://archive.org/download/StyleGANDatasets/Rococo.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Rococo.zip' -d /content/
  dataset_path= "/content/Rococo" 

if Dataset is "Ukiyo_e":
  # !wget https://archive.org/download/StyleGANDatasets/Ukiyo_e.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Ukiyo_e.zip' -d /content/
  dataset_path= "/content/Ukiyo_e"

if Dataset is "pop_art":
  # !wget https://archive.org/download/StyleGANDatasets/pop_art.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/pop_art.zip' -d /content/
  dataset_path= "/content/pop_art"

if Dataset is "Art_Nouveau_Modern":
  # !wget https://archive.org/download/Art_Nouveau_Modern/Art_Nouveau_Modern.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Art_Nouveau_Modern.zip' -d /content/
  dataset_path= "/content/Art_Nouveau_Modern"

if Dataset is "baroque":
  # !wget https://archive.org/download/BaroqueDataset/baroque.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/baroque.zip' -d /content/
  dataset_path= "/content/baroque"

if Dataset is "Expressionism":
  # !wget https://archive.org/download/expressionism/expressionism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/expressionism.zip' -d /content/
  dataset_path= "/content/expressionism"

if Dataset is "Naive_Art_Primitivism":
  # !wget https://archive.org/download/Naive_Art_Primitivism/Naive_Art_Primitivism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Naive_Art_Primitivism.zip' -d /content/
  dataset_path= "/content/Naive_Art_Primitivism"

if Dataset is "Impressionism":
  # !wget https://archive.org/download/ImpressionismArt/Impressionism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Impressionism.zip' -d /content/
  dataset_path= "/content/Impressionism" 

if Dataset is "Northern_Renaissance":
  # !wget https://archive.org/download/Northern_Renaissance/Northern_Renaissance.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Northern_Renaissance.zip' -d /content/
  dataset_path= "/content/Northern_Renaissance"

if Dataset is "Post_Impressionism":
  # !wget https://archive.org/download/Post_Impressionism/Post_Impressionism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Post_Impressionism.zip' -d /content/
  dataset_path= "/content/Post_Impressionism"

if Dataset is "Realism":
  # !wget https://archive.org/download/RealismData/Realism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Realism.zip' -d /content/
  dataset_path= "/content/Realism"  

if Dataset is "Romanticism":
  # !wget https://archive.org/download/RomanticismData/Romanticism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Romanticism.zip' -d /content/   
  dataset_path= "/content/Romanticism" 

if Dataset is "Symbolism":
  # !wget https://archive.org/download/SymbolismData/Symbolism.zip -q --show-progress
  # !unzip '/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/Symbolism.zip' -d /content/   
  dataset_path= "/content/Symbolism"
# %cd ..
# Out:
# /content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets
# pressionism.zip      12%[=>                  ] 490.94M   574KB/s    eta 2h 56m

# %% [markdown]
# ### **Training**
#
# Now for the waiting game. Check out my tutorial for a full explantation of the parameters. You can review progress by checking the samples in the results folder. Stop the execution to halt the training process.

# %%
# **FOR CUSTOM DATASETS ONLY**
dataset_path= "/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/dataset.zip"

# %%
#how often should the model generate samples and a .pkl file
snapshot_count = 4
#metrics? 
metric_list = "none"
#augments
augs = "ada"
augpipe= "bgcfnc"

# running it for the first time? set it to ffhq(+resolution)
# resuming? get the path to your latest .pkl file and use that
resume_from = "ffhq1024"

#don't edit this unless you know what you're doing :)
# !python train.py --outdir ./results --snap={snapshot_count} --cfg=paper1024 --data={dataset_path}  --metrics={metric_list} --resume={resume_from} --augpipe={augpipe} --aug={augs}
# Out:
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 4,
#   "network_snapshot_ticks": 4,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/dataset.zip",
#     "use_labels": false,
#     "max_size": 1135,
#     "xflip": false,
#     "resolution": 1024
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 8
#     },
#     "synthesis_kwargs": {
#       "channel_base": 32768,
#       "channel_max": 512,
#       "num_fp16_res": 4,
#       "conv_clamp": 256
#     }
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.002,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.002,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 2
#   },
#   "total_kimg": 25000,
#   "batch_size": 32,
#   "batch_gpu": 4,
#   "ema_kimg": 10,
#   "ema_rampup": null,
#   "ada_target": 0.6,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1,
#     "imgfilter": 1,
#     "noise": 1,
#     "cutout": 1
#   },
#   "resume_pkl": "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res1024-mirror-stylegan2-noaug.pkl",
#   "ada_kimg": 100,
#   "run_dir": "./results/00001-dataset-paper1024-ada-bgcfnc-resumeffhq1024"
# }
#
# Output directory:   ./results/00001-dataset-paper1024-ada-bgcfnc-resumeffhq1024
# Training data:      /content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/datasets/dataset.zip
# Training duration:  25000 kimg
# Number of GPUs:     1
# Number of images:   1135
# Image resolution:   1024
# Conditional model:  False
# Dataset x-flips:    False
#
# Creating output directory...
# Launching processes...
# Loading training set...
#
# Num images:  1135
# Image shape: [3, 1024, 1024]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res1024-mirror-stylegan2-noaug.pkl"
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/transfer-learning-source-nets/ffhq-res1024-mirror-stylegan2-noaug.pkl ... done
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Generator              Parameters  Buffers  Output shape         Datatype
# ---                    ---         ---      ---                  ---
# mapping.fc0            262656      -        [4, 512]             float32
# mapping.fc1            262656      -        [4, 512]             float32
# mapping.fc2            262656      -        [4, 512]             float32
# mapping.fc3            262656      -        [4, 512]             float32
# mapping.fc4            262656      -        [4, 512]             float32
# mapping.fc5            262656      -        [4, 512]             float32
# mapping.fc6            262656      -        [4, 512]             float32
# mapping.fc7            262656      -        [4, 512]             float32
# mapping                -           512      [4, 18, 512]         float32
# synthesis.b4.conv1     2622465     32       [4, 512, 4, 4]       float32
# synthesis.b4.torgb     264195      -        [4, 3, 4, 4]         float32
# synthesis.b4:0         8192        16       [4, 512, 4, 4]       float32
# synthesis.b4:1         -           -        [4, 512, 4, 4]       float32
# synthesis.b8.conv0     2622465     80       [4, 512, 8, 8]       float32
# synthesis.b8.conv1     2622465     80       [4, 512, 8, 8]       float32
# synthesis.b8.torgb     264195      -        [4, 3, 8, 8]         float32
# synthesis.b8:0         -           16       [4, 512, 8, 8]       float32
# synthesis.b8:1         -           -        [4, 512, 8, 8]       float32
# synthesis.b16.conv0    2622465     272      [4, 512, 16, 16]     float32
# synthesis.b16.conv1    2622465     272      [4, 512, 16, 16]     float32
# synthesis.b16.torgb    264195      -        [4, 3, 16, 16]       float32
# synthesis.b16:0        -           16       [4, 512, 16, 16]     float32
# synthesis.b16:1        -           -        [4, 512, 16, 16]     float32
# synthesis.b32.conv0    2622465     1040     [4, 512, 32, 32]     float32
# synthesis.b32.conv1    2622465     1040     [4, 512, 32, 32]     float32
# synthesis.b32.torgb    264195      -        [4, 3, 32, 32]       float32
# synthesis.b32:0        -           16       [4, 512, 32, 32]     float32
# synthesis.b32:1        -           -        [4, 512, 32, 32]     float32
# synthesis.b64.conv0    2622465     4112     [4, 512, 64, 64]     float32
# synthesis.b64.conv1    2622465     4112     [4, 512, 64, 64]     float32
# synthesis.b64.torgb    264195      -        [4, 3, 64, 64]       float32
# synthesis.b64:0        -           16       [4, 512, 64, 64]     float32
# synthesis.b64:1        -           -        [4, 512, 64, 64]     float32
# synthesis.b128.conv0   1442561     16400    [4, 256, 128, 128]   float16
# synthesis.b128.conv1   721409      16400    [4, 256, 128, 128]   float16
# synthesis.b128.torgb   132099      -        [4, 3, 128, 128]     float16
# synthesis.b128:0       -           16       [4, 256, 128, 128]   float16
# synthesis.b128:1       -           -        [4, 256, 128, 128]   float32
# synthesis.b256.conv0   426369      65552    [4, 128, 256, 256]   float16
# synthesis.b256.conv1   213249      65552    [4, 128, 256, 256]   float16
# synthesis.b256.torgb   66051       -        [4, 3, 256, 256]     float16
# synthesis.b256:0       -           16       [4, 128, 256, 256]   float16
# synthesis.b256:1       -           -        [4, 128, 256, 256]   float32
# synthesis.b512.conv0   139457      262160   [4, 64, 512, 512]    float16
# synthesis.b512.conv1   69761       262160   [4, 64, 512, 512]    float16
# synthesis.b512.torgb   33027       -        [4, 3, 512, 512]     float16
# synthesis.b512:0       -           16       [4, 64, 512, 512]    float16
# synthesis.b512:1       -           -        [4, 64, 512, 512]    float32
# synthesis.b1024.conv0  51297       1048592  [4, 32, 1024, 1024]  float16
# synthesis.b1024.conv1  25665       1048592  [4, 32, 1024, 1024]  float16
# synthesis.b1024.torgb  16515       -        [4, 3, 1024, 1024]   float16
# synthesis.b1024:0      -           16       [4, 32, 1024, 1024]  float16
# synthesis.b1024:1      -           -        [4, 32, 1024, 1024]  float32
# ---                    ---         ---      ---                  ---
# Total                  30370060    2797104  -                    -
#
#
# Discriminator  Parameters  Buffers  Output shape         Datatype
# ---            ---         ---      ---                  ---
# b1024.fromrgb  128         16       [4, 32, 1024, 1024]  float16
# b1024.skip     2048        16       [4, 64, 512, 512]    float16
# b1024.conv0    9248        16       [4, 32, 1024, 1024]  float16
# b1024.conv1    18496       16       [4, 64, 512, 512]    float16
# b1024          -           16       [4, 64, 512, 512]    float16
# b512.skip      8192        16       [4, 128, 256, 256]   float16
# b512.conv0     36928       16       [4, 64, 512, 512]    float16
# b512.conv1     73856       16       [4, 128, 256, 256]   float16
# b512           -           16       [4, 128, 256, 256]   float16
# b256.skip      32768       16       [4, 256, 128, 128]   float16
# b256.conv0     147584      16       [4, 128, 256, 256]   float16
# b256.conv1     295168      16       [4, 256, 128, 128]   float16
# b256           -           16       [4, 256, 128, 128]   float16
# b128.skip      131072      16       [4, 512, 64, 64]     float16
# b128.conv0     590080      16       [4, 256, 128, 128]   float16
# b128.conv1     1180160     16       [4, 512, 64, 64]     float16
# b128           -           16       [4, 512, 64, 64]     float16
# b64.skip       262144      16       [4, 512, 32, 32]     float32
# b64.conv0      2359808     16       [4, 512, 64, 64]     float32
# b64.conv1      2359808     16       [4, 512, 32, 32]     float32
# b64            -           16       [4, 512, 32, 32]     float32
# b32.skip       262144      16       [4, 512, 16, 16]     float32
# b32.conv0      2359808     16       [4, 512, 32, 32]     float32
# b32.conv1      2359808     16       [4, 512, 16, 16]     float32
# b32            -           16       [4, 512, 16, 16]     float32
# b16.skip       262144      16       [4, 512, 8, 8]       float32
# b16.conv0      2359808     16       [4, 512, 16, 16]     float32
# b16.conv1      2359808     16       [4, 512, 8, 8]       float32
# b16            -           16       [4, 512, 8, 8]       float32
# b8.skip        262144      16       [4, 512, 4, 4]       float32
# b8.conv0       2359808     16       [4, 512, 8, 8]       float32
# b8.conv1       2359808     16       [4, 512, 4, 4]       float32
# b8             -           16       [4, 512, 4, 4]       float32
# b4.mbstd       -           -        [4, 513, 4, 4]       float32
# b4.conv        2364416     16       [4, 512, 4, 4]       float32
# b4.fc          4194816     -        [4, 512]             float32
# b4.out         513         -        [4, 1]               float32
# ---            ---         ---      ---                  ---
# Total          29012513    544      -                    -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# 2021-05-17 15:58:49.585222: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Training for 25000 kimg...
#
# tick 0     kimg 0.0      time 2m 29s       sec/tick 43.4    sec/kimg 1357.76 maintenance 105.9  cpumem 5.71   gpumem 12.48  augment 0.000
# Evaluating metrics...
# {"results": {"fid50k_full": 239.91615849144145}, "metric": "fid50k_full", "total_time": 2758.3683047294617, "total_time_str": "45m 58s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1621269950.6615927}
# tick 1     kimg 4.0      time 1h 27m 13s   sec/tick 2307.8  sec/kimg 576.96  maintenance 2776.0 cpumem 5.92   gpumem 8.25   augment 0.031
# tick 2     kimg 8.0      time 2h 05m 52s   sec/tick 2318.2  sec/kimg 579.56  maintenance 0.3    cpumem 5.90   gpumem 8.26   augment 0.060
# tick 3     kimg 12.0     time 2h 44m 29s   sec/tick 2317.5  sec/kimg 579.37  maintenance 0.3    cpumem 5.88   gpumem 8.49   augment 0.086
# tick 4     kimg 16.0     time 3h 23m 15s   sec/tick 2325.9  sec/kimg 581.48  maintenance 0.0    cpumem 5.87   gpumem 8.44   augment 0.120
# Evaluating metrics...

# %% [markdown]
# Want to add or modify parameters? Read this to see more arugments

# %%
# !python train.py --help
# Out:
# Usage: train.py [OPTIONS]
#
#   Train a GAN using the techniques described in
#   the paper "Training Generative Adversarial
#   Networks with Limited Data".
#
#   Examples:
#
#   # Train with custom dataset using 1 GPU.
#   python train.py --outdir=~/training-runs --data=~/mydataset.zip --gpus=1
#
#   # Train class-conditional CIFAR-10 using 2 GPUs.
#   python train.py --outdir=~/training-runs --data=~/datasets/cifar10.zip \
#       --gpus=2 --cfg=cifar --cond=1
#
#   # Transfer learn MetFaces from FFHQ using 4 GPUs.
#   python train.py --outdir=~/training-runs --data=~/datasets/metfaces.zip \
#       --gpus=4 --cfg=paper1024 --mirror=1 --resume=ffhq1024 --snap=10
#
#   # Reproduce original StyleGAN2 config F.
#   python train.py --outdir=~/training-runs --data=~/datasets/ffhq.zip \
#       --gpus=8 --cfg=stylegan2 --mirror=1 --aug=noaug
#
#   Base configs (--cfg):
#     auto       Automatically select reasonable defaults based on resolution
#                and GPU count. Good starting point for new datasets.
#     stylegan2  Reproduce results for StyleGAN2 config F at 1024x1024.
#     paper256   Reproduce results for FFHQ and LSUN Cat at 256x256.
#     paper512   Reproduce results for BreCaHAD and AFHQ at 512x512.
#     paper1024  Reproduce results for MetFaces at 1024x1024.
#     cifar      Reproduce results for CIFAR-10 at 32x32.
#
#   Transfer learning source networks (--resume):
#     ffhq256        FFHQ trained at 256x256 resolution.
#     ffhq512        FFHQ trained at 512x512 resolution.
#     ffhq1024       FFHQ trained at 1024x1024 resolution.
#     celebahq256    CelebA-HQ trained at 256x256 resolution.
#     lsundog256     LSUN Dog trained at 256x256 resolution.
#     <PATH or URL>  Custom network pickle.
#
# Options:
#   --outdir DIR                    Where to save
#                                   the results
#                                   [required]
#
#   --gpus INT                      Number of GPUs
#                                   to use [default:
#                                   1]
#
#   --snap INT                      Snapshot
#                                   interval
#                                   [default: 50
#                                   ticks]
#
#   --metrics LIST                  Comma-separated
#                                   list or "none"
#                                   [default:
#                                   fid50k_full]
#
#   --seed INT                      Random seed
#                                   [default: 0]
#
#   -n, --dry-run                   Print training
#                                   options and exit
#
#   --data PATH                     Training data
#                                   (directory or
#                                   zip)  [required]
#
#   --cond BOOL                     Train
#                                   conditional
#                                   model based on
#                                   dataset labels
#                                   [default: false]
#
#   --subset INT                    Train with only
#                                   N images
#                                   [default: all]
#
#   --mirror BOOL                   Enable dataset
#                                   x-flips
#                                   [default: false]
#
#   --cfg [auto|stylegan2|paper256|paper512|paper1024|cifar]
#                                   Base config
#                                   [default: auto]
#
#   --gamma FLOAT                   Override R1
#                                   gamma
#
#   --kimg INT                      Override
#                                   training
#                                   duration
#
#   --batch INT                     Override batch
#                                   size
#
#   --aug [noaug|ada|fixed]         Augmentation
#                                   mode [default:
#                                   ada]
#
#   --p FLOAT                       Augmentation
#                                   probability for
#                                   --aug=fixed
#
#   --target FLOAT                  ADA target value
#                                   for --aug=ada
#
#   --augpipe [blit|geom|color|filter|noise|cutout|bg|bgc|bgcf|bgcfn|bgcfnc]
#                                   Augmentation
#                                   pipeline
#                                   [default: bgc]
#
#   --resume PKL                    Resume training
#                                   [default:
#                                   noresume]
#
#   --freezed INT                   Freeze-D
#                                   [default: 0
#                                   layers]
#
#   --fp32 BOOL                     Disable mixed-
#                                   precision
#                                   training
#
#   --nhwc BOOL                     Use NHWC memory
#                                   format with FP16
#
#   --nobench BOOL                  Disable cuDNN
#                                   benchmarking
#
#   --allow-tf32 BOOL               Allow PyTorch to
#                                   use TF32
#                                   internally
#
#   --workers INT                   Override number
#                                   of DataLoader
#                                   workers
#
#   --help                          Show this
#                                   message and
#                                   exit.

# %% [markdown]
# ### **Generating Images**
#
# Nice! When you got your .pkl file that you like best, you can generate images.
#
# First, copy the path of your .pkl file, and choose the seeds in which you want generated (ex 100-200 would generate 102 images)

# %%
num_images = 10-45
network_pkl = "/content/drive/MyDrive/py-sg2-ada/stylegan2-ada-pytorch/results/00002-dataset-mirror-paper1024-bg-resumecustom/network-snapshot-000496.pkl"

# %% [markdown]
# Run This to generate the images

# %%
# !python generate.py --network={network_pkl} --seeds=10-400 --outdir output/

# %% [markdown]
# You can now zip these images to easily download into your local machine.

# %%
# !zip -r generated-images.zip /output

# %% [markdown]
# ## **This is not the end of the possibilities. With your pkl file, there are countless applications that I could not cover in one document. This is an amazing tool to not only have fun but dip your toes into the AI world.**
